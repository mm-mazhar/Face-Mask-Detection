# %% [markdown]
# # 0. Setup Paths

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip list

# %%
import os
import tensorflow as tf

# %%
#rm -rf "/content/drive/MyDrive/TFOD1.x"

# %%
#print(tf.config.list_physical_devices('GPU'))

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
########################################################
##################  For Colab  #########################
########################################################

if not os.path.exists("/content/drive/MyDrive/TFOD/"):
  # !mkdir -p "/content/drive/MyDrive/TFOD/"

# %%
cd '/content/drive/MyDrive/TFOD/'
# Out:
# /content/drive/MyDrive/TFOD

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord_edited_for_kaggle_Dataset.py'
LABEL_MAP_NAME = 'label_map.pbtxt'
TRAINING_STEPS = 100000

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
    }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
files
# Out:
# {'PIPELINE_CONFIG': 'Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config',
#  'TF_RECORD_SCRIPT': 'Tensorflow/scripts/generate_tfrecord_edited_for_kaggle_Dataset.py',
#  'LABELMAP': 'Tensorflow/workspace/annotations/label_map.pbtxt'}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
paths
# Out:
# {'WORKSPACE_PATH': 'Tensorflow/workspace',
#  'SCRIPTS_PATH': 'Tensorflow/scripts',
#  'APIMODEL_PATH': 'Tensorflow/models',
#  'ANNOTATION_PATH': 'Tensorflow/workspace/annotations',
#  'IMAGE_PATH': 'Tensorflow/workspace/images',
#  'MODEL_PATH': 'Tensorflow/workspace/models',
#  'PRETRAINED_MODEL_PATH': 'Tensorflow/workspace/pre-trained-models',
#  'CHECKPOINT_PATH': 'Tensorflow/workspace/models/my_ssd_mobnet',
#  'OUTPUT_PATH': 'Tensorflow/workspace/models/my_ssd_mobnet/export',
#  'TFJS_PATH': 'Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport',
#  'TFLITE_PATH': 'Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport',
#  'PROTOC_PATH': 'Tensorflow/protoc'}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    #url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.19.6/protoc-3.19.6-win64.zip"
    wget.download(url)
    #!move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !move protoc-3.19.6-win64.zip {paths['PROTOC_PATH']}
    #!cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.19.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/TFOD/Tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.42.0-cp37-cp37m-manylinux2010_x86_64.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 8.1 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.9.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 67.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.5)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.10.0-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 40.5 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.27.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.0 MB)
#      |████████████████████████████████| 25.0 MB 44.6 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.9.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.4 MB/s
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 42.5 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.21.6)
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.6.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Collecting immutabledict
#   Downloading immutabledict-2.2.1-py3-none-any.whl (4.0 kB)
# Collecting tensorflow-text~=2.10.0
#   Downloading tensorflow_text-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 38.9 MB/s
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 52.1 MB/s
# Collecting tensorflow~=2.10.0
#   Downloading tensorflow-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      |████████████████████████████████| 578.0 MB 9.5 kB/s
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 44.7 MB/s
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Collecting opencv-python-headless==4.5.2.52
#   Downloading opencv_python_headless-4.5.2.52-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 1.2 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.8 MB/s
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 7.7 MB/s
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 40.2 MB/s
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 44.7 MB/s
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.4)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.9.24)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.27.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Collecting keras
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 39.7 MB/s
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 60.4 MB/s
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.9.24-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 43.8 MB/s
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.49.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.9.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.22.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.6 MB/s
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Collecting orjson<4.0
#   Downloading orjson-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (270 kB)
#      |████████████████████████████████| 270 kB 52.0 MB/s
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.6.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 34.6 MB/s
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 47.7 MB/s
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 59.1 MB/s
# Collecting cloudpickle~=2.1.0
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.12.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (508 kB)
#      |████████████████████████████████| 508 kB 54.2 MB/s
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting protobuf<4.0.0dev,>=3.12.0
#   Downloading protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 58.3 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.10.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.8.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.10.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Building wheels for collected packages: object-detection, py-cpuinfo, dill, avro-python3, docopt, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696507 sha256=2094960de9d324e8cbd2ea50b61dc7bbd03fc441000e9594b0a6efe1b4934d1b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nzn4_lne/wheels/4b/b4/ad/8028d318c13260939e98d62b4d2d07af40838d1fce0711162f
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=f2f1d20fc84d455a5b0c2dc6b289ccd108cda6824a0ea09f5bd55b28d97a6eac
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=7412324b560bb410544038c6b64ab423e7cefd5f2e836acb31fe3cfcf9eb9a48
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44010 sha256=a9c24f0bd91434891442d481a5e467c07fcbbc3b1926cee7e20406cdb84945c5
#   Stored in directory: /root/.cache/pip/wheels/d6/e5/b1/6b151d9b535ee50aaa6ab27d145a0104b6df02e5636f0376da
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=1dd7313c0ee21e2c731c1c3f5c10465cef6f13ef607ee670644485402893c8e4
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=922834f92e30bac1e67875cc58d68f258fd17e39875928d954ff4dba28a2fd03
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection py-cpuinfo dill avro-python3 docopt seqeval
# Installing collected packages: requests, pyparsing, protobuf, tensorflow-estimator, tensorboard, keras, flatbuffers, tensorflow, portalocker, docopt, dill, colorama, zstandard, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, pymongo, py-cpuinfo, proto-plus, orjson, opencv-python-headless, immutabledict, hdfs, fastavro, cloudpickle, tf-models-official, tensorflow-io, lvis, avro-python3, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.2.0
#     Uninstalling pymongo-4.2.0:
#       Successfully uninstalled pymongo-4.2.0
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.6.0.66
#     Uninstalling opencv-python-headless-4.6.0.66:
#       Successfully uninstalled opencv-python-headless-4.6.0.66
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.5.0
#     Uninstalling cloudpickle-1.5.0:
#       Successfully uninstalled cloudpickle-1.5.0
# Successfully installed apache-beam-2.42.0 avro-python3-1.10.2 cloudpickle-2.1.0 colorama-0.4.5 dill-0.3.1.1 docopt-0.6.2 fastavro-1.6.1 flatbuffers-22.9.24 hdfs-2.7.0 immutabledict-2.2.1 keras-2.10.0 lvis-0.5.3 object-detection-0.1 opencv-python-headless-4.5.2.52 orjson-3.8.0 portalocker-2.6.0 proto-plus-1.22.1 protobuf-3.19.6 py-cpuinfo-8.0.0 pymongo-3.12.3 pyparsing-2.4.7 pyyaml-5.4.1 requests-2.28.1 sacrebleu-2.2.0 sentencepiece-0.1.97 seqeval-1.2.2 tensorboard-2.10.1 tensorflow-2.10.0 tensorflow-addons-0.18.0 tensorflow-estimator-2.10.0 tensorflow-io-0.27.0 tensorflow-model-optimization-0.7.3 tensorflow-text-2.10.0 tf-models-official-2.10.0 tf-slim-1.1.0 zstandard-0.18.0

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2022-10-20 18:54:06.666613: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-20 18:54:09.080176: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-10-20 18:54:09.081676: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-10-20 18:54:09.081839: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-10-20 18:54:17.927013: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Running tests under Python 3.7.15: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# W1020 18:54:18.769325 139914318219136 model_builder.py:1109] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.41s
# I1020 18:54:19.340273 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.41s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.27s
# I1020 18:54:20.607594 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.27s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.72s
# I1020 18:54:21.327861 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.72s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.89s
# I1020 18:54:22.217901 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.89s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 6.59s
# I1020 18:54:28.805148 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 6.59s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1020 18:54:28.815797 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.09s
# I1020 18:54:28.909839 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.07s
# I1020 18:54:28.985736 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.04s
# I1020 18:54:29.031709 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.04s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.29s
# I1020 18:54:29.325502 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.29s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.29s
# I1020 18:54:29.616129 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.29s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.24s
# I1020 18:54:29.857446 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.35s
# I1020 18:54:30.221969 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.35s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.35s
# I1020 18:54:30.577068 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.35s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.06s
# I1020 18:54:30.634422 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I1020 18:54:30.899215 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1020 18:54:30.899418 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet BiFPN num filters: 64
# I1020 18:54:30.899484 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# I1020 18:54:30.902526 139914318219136 efficientnet_model.py:143] round_filter input=32 output=32
# I1020 18:54:30.936749 139914318219136 efficientnet_model.py:143] round_filter input=32 output=32
# I1020 18:54:30.936959 139914318219136 efficientnet_model.py:143] round_filter input=16 output=16
# I1020 18:54:31.051717 139914318219136 efficientnet_model.py:143] round_filter input=16 output=16
# I1020 18:54:31.051929 139914318219136 efficientnet_model.py:143] round_filter input=24 output=24
# I1020 18:54:31.343188 139914318219136 efficientnet_model.py:143] round_filter input=24 output=24
# I1020 18:54:31.343406 139914318219136 efficientnet_model.py:143] round_filter input=40 output=40
# I1020 18:54:31.602678 139914318219136 efficientnet_model.py:143] round_filter input=40 output=40
# I1020 18:54:31.602892 139914318219136 efficientnet_model.py:143] round_filter input=80 output=80
# I1020 18:54:31.972860 139914318219136 efficientnet_model.py:143] round_filter input=80 output=80
# I1020 18:54:31.973086 139914318219136 efficientnet_model.py:143] round_filter input=112 output=112
# I1020 18:54:32.618910 139914318219136 efficientnet_model.py:143] round_filter input=112 output=112
# I1020 18:54:32.619332 139914318219136 efficientnet_model.py:143] round_filter input=192 output=192
# I1020 18:54:33.319433 139914318219136 efficientnet_model.py:143] round_filter input=192 output=192
# I1020 18:54:33.319669 139914318219136 efficientnet_model.py:143] round_filter input=320 output=320
# I1020 18:54:33.489441 139914318219136 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1020 18:54:33.585549 139914318219136 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1020 18:54:33.666723 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1020 18:54:33.666996 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet BiFPN num filters: 88
# I1020 18:54:33.667125 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 4
# I1020 18:54:33.670427 139914318219136 efficientnet_model.py:143] round_filter input=32 output=32
# I1020 18:54:33.699757 139914318219136 efficientnet_model.py:143] round_filter input=32 output=32
# I1020 18:54:33.699967 139914318219136 efficientnet_model.py:143] round_filter input=16 output=16
# I1020 18:54:33.938614 139914318219136 efficientnet_model.py:143] round_filter input=16 output=16
# I1020 18:54:33.938840 139914318219136 efficientnet_model.py:143] round_filter input=24 output=24
# I1020 18:54:34.382159 139914318219136 efficientnet_model.py:143] round_filter input=24 output=24
# I1020 18:54:34.382390 139914318219136 efficientnet_model.py:143] round_filter input=40 output=40
# I1020 18:54:34.768433 139914318219136 efficientnet_model.py:143] round_filter input=40 output=40
# I1020 18:54:34.768669 139914318219136 efficientnet_model.py:143] round_filter input=80 output=80
# I1020 18:54:35.315644 139914318219136 efficientnet_model.py:143] round_filter input=80 output=80
# I1020 18:54:35.315867 139914318219136 efficientnet_model.py:143] round_filter input=112 output=112
# I1020 18:54:35.809819 139914318219136 efficientnet_model.py:143] round_filter input=112 output=112
# I1020 18:54:35.810024 139914318219136 efficientnet_model.py:143] round_filter input=192 output=192
# I1020 18:54:36.466763 139914318219136 efficientnet_model.py:143] round_filter input=192 output=192
# I1020 18:54:36.466977 139914318219136 efficientnet_model.py:143] round_filter input=320 output=320
# I1020 18:54:36.761899 139914318219136 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1020 18:54:36.835066 139914318219136 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1020 18:54:36.910276 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b2
# I1020 18:54:36.910507 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet BiFPN num filters: 112
# I1020 18:54:36.910576 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 5
# I1020 18:54:36.913181 139914318219136 efficientnet_model.py:143] round_filter input=32 output=32
# I1020 18:54:36.935624 139914318219136 efficientnet_model.py:143] round_filter input=32 output=32
# I1020 18:54:36.935832 139914318219136 efficientnet_model.py:143] round_filter input=16 output=16
# I1020 18:54:37.118707 139914318219136 efficientnet_model.py:143] round_filter input=16 output=16
# I1020 18:54:37.118915 139914318219136 efficientnet_model.py:143] round_filter input=24 output=24
# I1020 18:54:37.461566 139914318219136 efficientnet_model.py:143] round_filter input=24 output=24
# I1020 18:54:37.461777 139914318219136 efficientnet_model.py:143] round_filter input=40 output=48
# I1020 18:54:37.828065 139914318219136 efficientnet_model.py:143] round_filter input=40 output=48
# I1020 18:54:37.828288 139914318219136 efficientnet_model.py:143] round_filter input=80 output=88
# I1020 18:54:38.330006 139914318219136 efficientnet_model.py:143] round_filter input=80 output=88
# I1020 18:54:38.330373 139914318219136 efficientnet_model.py:143] round_filter input=112 output=120
# I1020 18:54:38.848066 139914318219136 efficientnet_model.py:143] round_filter input=112 output=120
# I1020 18:54:38.848291 139914318219136 efficientnet_model.py:143] round_filter input=192 output=208
# I1020 18:54:39.546590 139914318219136 efficientnet_model.py:143] round_filter input=192 output=208
# I1020 18:54:39.546818 139914318219136 efficientnet_model.py:143] round_filter input=320 output=352
# I1020 18:54:39.884297 139914318219136 efficientnet_model.py:143] round_filter input=1280 output=1408
# I1020 18:54:39.974164 139914318219136 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1020 18:54:40.052561 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I1020 18:54:40.052811 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet BiFPN num filters: 160
# I1020 18:54:40.052890 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I1020 18:54:40.054933 139914318219136 efficientnet_model.py:143] round_filter input=32 output=40
# I1020 18:54:40.080671 139914318219136 efficientnet_model.py:143] round_filter input=32 output=40
# I1020 18:54:40.080899 139914318219136 efficientnet_model.py:143] round_filter input=16 output=24
# I1020 18:54:40.279318 139914318219136 efficientnet_model.py:143] round_filter input=16 output=24
# I1020 18:54:40.279523 139914318219136 efficientnet_model.py:143] round_filter input=24 output=32
# I1020 18:54:40.640417 139914318219136 efficientnet_model.py:143] round_filter input=24 output=32
# I1020 18:54:40.640629 139914318219136 efficientnet_model.py:143] round_filter input=40 output=48
# I1020 18:54:41.270031 139914318219136 efficientnet_model.py:143] round_filter input=40 output=48
# I1020 18:54:41.270269 139914318219136 efficientnet_model.py:143] round_filter input=80 output=96
# I1020 18:54:41.894841 139914318219136 efficientnet_model.py:143] round_filter input=80 output=96
# I1020 18:54:41.895061 139914318219136 efficientnet_model.py:143] round_filter input=112 output=136
# I1020 18:54:42.610312 139914318219136 efficientnet_model.py:143] round_filter input=112 output=136
# I1020 18:54:42.610541 139914318219136 efficientnet_model.py:143] round_filter input=192 output=232
# I1020 18:54:43.675436 139914318219136 efficientnet_model.py:143] round_filter input=192 output=232
# I1020 18:54:43.675668 139914318219136 efficientnet_model.py:143] round_filter input=320 output=384
# I1020 18:54:44.082199 139914318219136 efficientnet_model.py:143] round_filter input=1280 output=1536
# I1020 18:54:44.189871 139914318219136 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1020 18:54:44.276800 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b4
# I1020 18:54:44.277025 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet BiFPN num filters: 224
# I1020 18:54:44.277244 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I1020 18:54:44.279909 139914318219136 efficientnet_model.py:143] round_filter input=32 output=48
# I1020 18:54:44.322662 139914318219136 efficientnet_model.py:143] round_filter input=32 output=48
# I1020 18:54:44.322920 139914318219136 efficientnet_model.py:143] round_filter input=16 output=24
# I1020 18:54:44.563643 139914318219136 efficientnet_model.py:143] round_filter input=16 output=24
# I1020 18:54:44.563874 139914318219136 efficientnet_model.py:143] round_filter input=24 output=32
# I1020 18:54:45.145570 139914318219136 efficientnet_model.py:143] round_filter input=24 output=32
# I1020 18:54:45.145926 139914318219136 efficientnet_model.py:143] round_filter input=40 output=56
# I1020 18:54:45.729255 139914318219136 efficientnet_model.py:143] round_filter input=40 output=56
# I1020 18:54:45.729485 139914318219136 efficientnet_model.py:143] round_filter input=80 output=112
# I1020 18:54:46.547331 139914318219136 efficientnet_model.py:143] round_filter input=80 output=112
# I1020 18:54:46.547549 139914318219136 efficientnet_model.py:143] round_filter input=112 output=160
# I1020 18:54:47.319656 139914318219136 efficientnet_model.py:143] round_filter input=112 output=160
# I1020 18:54:47.319863 139914318219136 efficientnet_model.py:143] round_filter input=192 output=272
# I1020 18:54:48.467630 139914318219136 efficientnet_model.py:143] round_filter input=192 output=272
# I1020 18:54:48.467862 139914318219136 efficientnet_model.py:143] round_filter input=320 output=448
# I1020 18:54:48.831473 139914318219136 efficientnet_model.py:143] round_filter input=1280 output=1792
# I1020 18:54:48.920105 139914318219136 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1020 18:54:49.018433 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1020 18:54:49.018643 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet BiFPN num filters: 288
# I1020 18:54:49.018708 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I1020 18:54:49.021468 139914318219136 efficientnet_model.py:143] round_filter input=32 output=48
# I1020 18:54:49.048572 139914318219136 efficientnet_model.py:143] round_filter input=32 output=48
# I1020 18:54:49.048897 139914318219136 efficientnet_model.py:143] round_filter input=16 output=24
# I1020 18:54:49.321427 139914318219136 efficientnet_model.py:143] round_filter input=16 output=24
# I1020 18:54:49.321659 139914318219136 efficientnet_model.py:143] round_filter input=24 output=40
# I1020 18:54:49.898632 139914318219136 efficientnet_model.py:143] round_filter input=24 output=40
# I1020 18:54:49.898843 139914318219136 efficientnet_model.py:143] round_filter input=40 output=64
# I1020 18:54:50.499187 139914318219136 efficientnet_model.py:143] round_filter input=40 output=64
# I1020 18:54:50.499416 139914318219136 efficientnet_model.py:143] round_filter input=80 output=128
# I1020 18:54:51.648094 139914318219136 efficientnet_model.py:143] round_filter input=80 output=128
# I1020 18:54:51.648371 139914318219136 efficientnet_model.py:143] round_filter input=112 output=176
# I1020 18:54:52.644374 139914318219136 efficientnet_model.py:143] round_filter input=112 output=176
# I1020 18:54:52.644613 139914318219136 efficientnet_model.py:143] round_filter input=192 output=304
# I1020 18:54:54.364516 139914318219136 efficientnet_model.py:143] round_filter input=192 output=304
# I1020 18:54:54.364763 139914318219136 efficientnet_model.py:143] round_filter input=320 output=512
# I1020 18:54:55.055459 139914318219136 efficientnet_model.py:143] round_filter input=1280 output=2048
# I1020 18:54:55.159559 139914318219136 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1020 18:54:55.274881 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I1020 18:54:55.275177 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet BiFPN num filters: 384
# I1020 18:54:55.275265 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I1020 18:54:55.277641 139914318219136 efficientnet_model.py:143] round_filter input=32 output=56
# I1020 18:54:55.303869 139914318219136 efficientnet_model.py:143] round_filter input=32 output=56
# I1020 18:54:55.304096 139914318219136 efficientnet_model.py:143] round_filter input=16 output=32
# I1020 18:54:55.588831 139914318219136 efficientnet_model.py:143] round_filter input=16 output=32
# I1020 18:54:55.589044 139914318219136 efficientnet_model.py:143] round_filter input=24 output=40
# I1020 18:54:56.304932 139914318219136 efficientnet_model.py:143] round_filter input=24 output=40
# I1020 18:54:56.305170 139914318219136 efficientnet_model.py:143] round_filter input=40 output=72
# I1020 18:54:57.020184 139914318219136 efficientnet_model.py:143] round_filter input=40 output=72
# I1020 18:54:57.020389 139914318219136 efficientnet_model.py:143] round_filter input=80 output=144
# I1020 18:54:58.011240 139914318219136 efficientnet_model.py:143] round_filter input=80 output=144
# I1020 18:54:58.011451 139914318219136 efficientnet_model.py:143] round_filter input=112 output=200
# I1020 18:54:59.049487 139914318219136 efficientnet_model.py:143] round_filter input=112 output=200
# I1020 18:54:59.049703 139914318219136 efficientnet_model.py:143] round_filter input=192 output=344
# I1020 18:55:00.846853 139914318219136 efficientnet_model.py:143] round_filter input=192 output=344
# I1020 18:55:00.847102 139914318219136 efficientnet_model.py:143] round_filter input=320 output=576
# I1020 18:55:01.526779 139914318219136 efficientnet_model.py:143] round_filter input=1280 output=2304
# I1020 18:55:01.631330 139914318219136 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1020 18:55:01.753101 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1020 18:55:01.753306 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:151] EfficientDet BiFPN num filters: 384
# I1020 18:55:01.753368 139914318219136 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I1020 18:55:01.755314 139914318219136 efficientnet_model.py:143] round_filter input=32 output=64
# I1020 18:55:01.780764 139914318219136 efficientnet_model.py:143] round_filter input=32 output=64
# I1020 18:55:01.780969 139914318219136 efficientnet_model.py:143] round_filter input=16 output=32
# I1020 18:55:02.193780 139914318219136 efficientnet_model.py:143] round_filter input=16 output=32
# I1020 18:55:02.194016 139914318219136 efficientnet_model.py:143] round_filter input=24 output=48
# I1020 18:55:03.638230 139914318219136 efficientnet_model.py:143] round_filter input=24 output=48
# I1020 18:55:03.638460 139914318219136 efficientnet_model.py:143] round_filter input=40 output=80
# I1020 18:55:04.644756 139914318219136 efficientnet_model.py:143] round_filter input=40 output=80
# I1020 18:55:04.644970 139914318219136 efficientnet_model.py:143] round_filter input=80 output=160
# I1020 18:55:06.037834 139914318219136 efficientnet_model.py:143] round_filter input=80 output=160
# I1020 18:55:06.038045 139914318219136 efficientnet_model.py:143] round_filter input=112 output=224
# I1020 18:55:07.436329 139914318219136 efficientnet_model.py:143] round_filter input=112 output=224
# I1020 18:55:07.436545 139914318219136 efficientnet_model.py:143] round_filter input=192 output=384
# I1020 18:55:09.695134 139914318219136 efficientnet_model.py:143] round_filter input=192 output=384
# I1020 18:55:09.695349 139914318219136 efficientnet_model.py:143] round_filter input=320 output=640
# I1020 18:55:10.724188 139914318219136 efficientnet_model.py:143] round_filter input=1280 output=2560
# I1020 18:55:10.841985 139914318219136 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 40.36s
# I1020 18:55:10.994059 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 40.36s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1020 18:55:11.026713 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1020 18:55:11.028870 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1020 18:55:11.030231 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1020 18:55:11.032137 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1020 18:55:11.033762 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1020 18:55:11.034265 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1020 18:55:11.035332 139914318219136 test_util.py:2461] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 53.103s
#
# OK (skipped=1)

# %%
# if you don't see 'OK (skipped=1)' thing in above cell then you must be encountered with errors
# just simply uninstall and re-install packages which are shown in the errors

# pip uninstall protobuf matplotlib -y
# pip install protobuf matplotlib==3.2.2
#!pip install tensorflow-gpu --upgrade
#!pip uninstall protobuf matplotlib -y
#!pip install protobuf matplotlib
#!pip install Pillow
#!pip install pyyaml==5.3.1

# %%
import object_detection

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2022-10-20 18:55:12--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 64.233.182.128, 2607:f8b0:4001:c0a::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|64.233.182.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  25.9MB/s    in 0.8s
#
# 2022-10-20 18:55:13 (25.9 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
files['LABELMAP']
# Out:
# 'Tensorflow/workspace/annotations/label_map.pbtxt'

# %%
labels = [{'name':'with_mask', 'id':1}, {'name':'without_mask', 'id':2}, {'name':'mask_weared_incorrect', 'id':3}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# #OPTIONAL IF RUNNING ON COLAB
# ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
# if os.path.exists(ARCHIVE_FILES):
#   !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/mazqoty/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
#os.path.join(paths['IMAGE_PATH'], 'train')               # Tensorflow/workspace/images/train
#files['TF_RECORD_SCRIPT']                                # Tensorflow/scripts/generate_tfrecord.py
#files['LABELMAP']                                        # Tensorflow/workspace/annotations/label_map.pbtxt
#os.path.join(paths['ANNOTATION_PATH'], 'train.record')   # Tensorflow/workspace/annotations/train.record

# %%
# #Create TFRecords from XML Files
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')} 

# # Create TFRecords from CSV Files
# !python {files['TF_RECORD_SCRIPT']} --csv_input={os.path.join(paths['IMAGE_PATH'], 'train', 'train.csv')} --image_dir={os.path.join(paths['IMAGE_PATH'], 'train')} --output_path={os.path.join(paths['ANNOTATION_PATH'], 'train.record')}
# !python {files['TF_RECORD_SCRIPT']} --csv_input={os.path.join(paths['IMAGE_PATH'], 'test', 'test.csv')} --image_dir={os.path.join(paths['IMAGE_PATH'], 'test')} --output_path={os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# 2022-10-20 18:55:17.457337: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-20 18:55:22.831804: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# 2022-10-20 18:56:08.936063: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-20 18:56:11.637953: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')
# Out:
# 'Tensorflow/workspace/pre-trained-models/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config'

# %%
os.path.join(paths['CHECKPOINT_PATH'])
# Out:
# 'Tensorflow/workspace/models/my_ssd_mobnet'

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
files['PIPELINE_CONFIG']
# Out:
# 'Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config'

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
#config

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %%
files['PIPELINE_CONFIG']
# Out:
# 'Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config'

# %%
custom_config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
#custom_config

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} \
--model_dir={} \
--pipeline_config_path={} \
--num_train_steps={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], TRAINING_STEPS)

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=100000

# %%
# !{command}
# Out:
# Streaming output truncated to the last 5000 lines.
#  'learning_rate': 0.0}
# I1020 07:04:01.526572 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.03903734,
#  'Loss/localization_loss': 0.016699374,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12221542,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 60300 per-step time 0.074s
# I1020 07:04:08.882604 140189347592064 model_lib_v2.py:707] Step 60300 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.024956418,
#  'Loss/localization_loss': 0.0065386947,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09797382,
#  'learning_rate': 0.0}
# I1020 07:04:08.882902 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.024956418,
#  'Loss/localization_loss': 0.0065386947,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09797382,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 60400 per-step time 0.074s
# I1020 07:04:16.303713 140189347592064 model_lib_v2.py:707] Step 60400 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.045160227,
#  'Loss/localization_loss': 0.0065918714,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.118230805,
#  'learning_rate': 0.0}
# I1020 07:04:16.304001 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.045160227,
#  'Loss/localization_loss': 0.0065918714,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.118230805,
#  'learning_rate': 0.0}
# 2022-10-20 07:04:17.918807: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 60500 per-step time 0.074s
# I1020 07:04:23.751078 140189347592064 model_lib_v2.py:707] Step 60500 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.039997775,
#  'Loss/localization_loss': 0.012803379,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11927986,
#  'learning_rate': 0.0}
# I1020 07:04:23.751417 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.039997775,
#  'Loss/localization_loss': 0.012803379,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11927986,
#  'learning_rate': 0.0}
# 2022-10-20 07:04:29.465527: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 60600 per-step time 0.075s
# I1020 07:04:31.278517 140189347592064 model_lib_v2.py:707] Step 60600 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.06063768,
#  'Loss/localization_loss': 0.016156951,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14327334,
#  'learning_rate': 0.0}
# I1020 07:04:31.278888 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06063768,
#  'Loss/localization_loss': 0.016156951,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14327334,
#  'learning_rate': 0.0}
# 2022-10-20 07:04:34.773493: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 60700 per-step time 0.075s
# I1020 07:04:38.766277 140189347592064 model_lib_v2.py:707] Step 60700 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.09392685,
#  'Loss/localization_loss': 0.045505963,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.20591152,
#  'learning_rate': 0.0}
# I1020 07:04:38.766577 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.09392685,
#  'Loss/localization_loss': 0.045505963,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.20591152,
#  'learning_rate': 0.0}
# 2022-10-20 07:04:40.140992: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 60800 per-step time 0.074s
# I1020 07:04:46.158287 140189347592064 model_lib_v2.py:707] Step 60800 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.052782297,
#  'Loss/localization_loss': 0.021832034,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14109305,
#  'learning_rate': 0.0}
# I1020 07:04:46.158585 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.052782297,
#  'Loss/localization_loss': 0.021832034,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14109305,
#  'learning_rate': 0.0}
# 2022-10-20 07:04:46.883611: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 60900 per-step time 0.073s
# I1020 07:04:53.480417 140189347592064 model_lib_v2.py:707] Step 60900 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.049471635,
#  'Loss/localization_loss': 0.030553812,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14650416,
#  'learning_rate': 0.0}
# I1020 07:04:53.480752 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.049471635,
#  'Loss/localization_loss': 0.030553812,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14650416,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 61000 per-step time 0.073s
# I1020 07:05:00.767046 140189347592064 model_lib_v2.py:707] Step 61000 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.06375086,
#  'Loss/localization_loss': 0.014314321,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14454389,
#  'learning_rate': 0.0}
# I1020 07:05:00.767336 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06375086,
#  'Loss/localization_loss': 0.014314321,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14454389,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 61100 per-step time 0.086s
# I1020 07:05:09.405394 140189347592064 model_lib_v2.py:707] Step 61100 per-step time 0.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.04602834,
#  'Loss/localization_loss': 0.024360834,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13686788,
#  'learning_rate': 0.0}
# I1020 07:05:09.405690 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.04602834,
#  'Loss/localization_loss': 0.024360834,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13686788,
#  'learning_rate': 0.0}
# 2022-10-20 07:05:12.872994: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 61200 per-step time 0.074s
# I1020 07:05:16.760440 140189347592064 model_lib_v2.py:707] Step 61200 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.049481846,
#  'Loss/localization_loss': 0.014998062,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13095862,
#  'learning_rate': 0.0}
# I1020 07:05:16.760739 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.049481846,
#  'Loss/localization_loss': 0.014998062,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13095862,
#  'learning_rate': 0.0}
# 2022-10-20 07:05:18.855977: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 61300 per-step time 0.072s
# I1020 07:05:24.003185 140189347592064 model_lib_v2.py:707] Step 61300 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.032280296,
#  'Loss/localization_loss': 0.010081326,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10884033,
#  'learning_rate': 0.0}
# I1020 07:05:24.003496 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.032280296,
#  'Loss/localization_loss': 0.010081326,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10884033,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 61400 per-step time 0.074s
# I1020 07:05:31.401234 140189347592064 model_lib_v2.py:707] Step 61400 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.045086768,
#  'Loss/localization_loss': 0.014395583,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12596107,
#  'learning_rate': 0.0}
# I1020 07:05:31.401551 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.045086768,
#  'Loss/localization_loss': 0.014395583,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12596107,
#  'learning_rate': 0.0}
# 2022-10-20 07:05:32.485706: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 61500 per-step time 0.075s
# I1020 07:05:38.928163 140189347592064 model_lib_v2.py:707] Step 61500 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.038140275,
#  'Loss/localization_loss': 0.009784632,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11440361,
#  'learning_rate': 0.0}
# I1020 07:05:38.928456 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.038140275,
#  'Loss/localization_loss': 0.009784632,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11440361,
#  'learning_rate': 0.0}
# 2022-10-20 07:05:43.417608: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 61600 per-step time 0.074s
# I1020 07:05:46.304127 140189347592064 model_lib_v2.py:707] Step 61600 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.03521708,
#  'Loss/localization_loss': 0.00890909,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11060488,
#  'learning_rate': 0.0}
# I1020 07:05:46.304458 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.03521708,
#  'Loss/localization_loss': 0.00890909,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11060488,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 61700 per-step time 0.076s
# I1020 07:05:53.862142 140189347592064 model_lib_v2.py:707] Step 61700 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.04404823,
#  'Loss/localization_loss': 0.015951324,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12647825,
#  'learning_rate': 0.0}
# I1020 07:05:53.862426 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.04404823,
#  'Loss/localization_loss': 0.015951324,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12647825,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 61800 per-step time 0.075s
# I1020 07:06:01.345885 140189347592064 model_lib_v2.py:707] Step 61800 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.0711582,
#  'Loss/localization_loss': 0.023686389,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1613233,
#  'learning_rate': 0.0}
# I1020 07:06:01.346190 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.0711582,
#  'Loss/localization_loss': 0.023686389,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1613233,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 61900 per-step time 0.075s
# I1020 07:06:08.833240 140189347592064 model_lib_v2.py:707] Step 61900 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.053058133,
#  'Loss/localization_loss': 0.015556692,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13509354,
#  'learning_rate': 0.0}
# I1020 07:06:08.833556 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.053058133,
#  'Loss/localization_loss': 0.015556692,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13509354,
#  'learning_rate': 0.0}
# 2022-10-20 07:06:14.305292: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 62000 per-step time 0.073s
# I1020 07:06:16.094831 140189347592064 model_lib_v2.py:707] Step 62000 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.037974868,
#  'Loss/localization_loss': 0.018072164,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12252574,
#  'learning_rate': 0.0}
# I1020 07:06:16.095177 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.037974868,
#  'Loss/localization_loss': 0.018072164,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12252574,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 62100 per-step time 0.084s
# I1020 07:06:24.441205 140189347592064 model_lib_v2.py:707] Step 62100 per-step time 0.084s
# INFO:tensorflow:{'Loss/classification_loss': 0.05600972,
#  'Loss/localization_loss': 0.012145629,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13463405,
#  'learning_rate': 0.0}
# I1020 07:06:24.441519 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.05600972,
#  'Loss/localization_loss': 0.012145629,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13463405,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 62200 per-step time 0.075s
# I1020 07:06:31.973496 140189347592064 model_lib_v2.py:707] Step 62200 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.04826917,
#  'Loss/localization_loss': 0.023026414,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13777429,
#  'learning_rate': 0.0}
# I1020 07:06:31.973785 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.04826917,
#  'Loss/localization_loss': 0.023026414,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13777429,
#  'learning_rate': 0.0}
# 2022-10-20 07:06:37.856825: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 62300 per-step time 0.073s
# I1020 07:06:39.300378 140189347592064 model_lib_v2.py:707] Step 62300 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.020400029,
#  'Loss/localization_loss': 0.0048016077,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09168035,
#  'learning_rate': 0.0}
# I1020 07:06:39.300696 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.020400029,
#  'Loss/localization_loss': 0.0048016077,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09168035,
#  'learning_rate': 0.0}
# 2022-10-20 07:06:45.731909: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# 2022-10-20 07:06:46.112816: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 62400 per-step time 0.074s
# I1020 07:06:46.728416 140189347592064 model_lib_v2.py:707] Step 62400 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.06983375,
#  'Loss/localization_loss': 0.0273788,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16369125,
#  'learning_rate': 0.0}
# I1020 07:06:46.728703 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06983375,
#  'Loss/localization_loss': 0.0273788,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16369125,
#  'learning_rate': 0.0}
# 2022-10-20 07:06:51.406306: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 62500 per-step time 0.075s
# I1020 07:06:54.202282 140189347592064 model_lib_v2.py:707] Step 62500 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.053133927,
#  'Loss/localization_loss': 0.01601442,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13562706,
#  'learning_rate': 0.0}
# I1020 07:06:54.202590 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.053133927,
#  'Loss/localization_loss': 0.01601442,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13562706,
#  'learning_rate': 0.0}
# 2022-10-20 07:06:56.769466: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 62600 per-step time 0.073s
# I1020 07:07:01.519494 140189347592064 model_lib_v2.py:707] Step 62600 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.033565674,
#  'Loss/localization_loss': 0.012099437,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.112143815,
#  'learning_rate': 0.0}
# I1020 07:07:01.519811 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.033565674,
#  'Loss/localization_loss': 0.012099437,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.112143815,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 62700 per-step time 0.075s
# I1020 07:07:09.018796 140189347592064 model_lib_v2.py:707] Step 62700 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.049011495,
#  'Loss/localization_loss': 0.010274156,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12576436,
#  'learning_rate': 0.0}
# I1020 07:07:09.019092 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.049011495,
#  'Loss/localization_loss': 0.010274156,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12576436,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 62800 per-step time 0.074s
# I1020 07:07:16.427144 140189347592064 model_lib_v2.py:707] Step 62800 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.049855266,
#  'Loss/localization_loss': 0.013262019,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.129596,
#  'learning_rate': 0.0}
# I1020 07:07:16.427545 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.049855266,
#  'Loss/localization_loss': 0.013262019,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.129596,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 62900 per-step time 0.081s
# I1020 07:07:24.548778 140189347592064 model_lib_v2.py:707] Step 62900 per-step time 0.081s
# INFO:tensorflow:{'Loss/classification_loss': 0.0899776,
#  'Loss/localization_loss': 0.030012522,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.18646884,
#  'learning_rate': 0.0}
# I1020 07:07:24.549153 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.0899776,
#  'Loss/localization_loss': 0.030012522,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.18646884,
#  'learning_rate': 0.0}
# 2022-10-20 07:07:26.525237: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 63000 per-step time 0.101s
# I1020 07:07:34.670246 140189347592064 model_lib_v2.py:707] Step 63000 per-step time 0.101s
# INFO:tensorflow:{'Loss/classification_loss': 0.04221759,
#  'Loss/localization_loss': 0.018706879,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12740317,
#  'learning_rate': 0.0}
# I1020 07:07:34.670560 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.04221759,
#  'Loss/localization_loss': 0.018706879,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12740317,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 63100 per-step time 0.082s
# I1020 07:07:42.896507 140189347592064 model_lib_v2.py:707] Step 63100 per-step time 0.082s
# INFO:tensorflow:{'Loss/classification_loss': 0.058815006,
#  'Loss/localization_loss': 0.012352342,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13764605,
#  'learning_rate': 0.0}
# I1020 07:07:42.896813 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.058815006,
#  'Loss/localization_loss': 0.012352342,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13764605,
#  'learning_rate': 0.0}
# 2022-10-20 07:07:49.514942: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 63200 per-step time 0.075s
# I1020 07:07:50.378766 140189347592064 model_lib_v2.py:707] Step 63200 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.04071741,
#  'Loss/localization_loss': 0.0070495973,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11424571,
#  'learning_rate': 0.0}
# I1020 07:07:50.379067 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.04071741,
#  'Loss/localization_loss': 0.0070495973,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11424571,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 63300 per-step time 0.075s
# I1020 07:07:57.901380 140189347592064 model_lib_v2.py:707] Step 63300 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.047414847,
#  'Loss/localization_loss': 0.010083466,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12397702,
#  'learning_rate': 0.0}
# I1020 07:07:57.901688 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.047414847,
#  'Loss/localization_loss': 0.010083466,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12397702,
#  'learning_rate': 0.0}
# 2022-10-20 07:08:00.411564: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 63400 per-step time 0.070s
# I1020 07:08:04.894065 140189347592064 model_lib_v2.py:707] Step 63400 per-step time 0.070s
# INFO:tensorflow:{'Loss/classification_loss': 0.045148026,
#  'Loss/localization_loss': 0.014572379,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12619911,
#  'learning_rate': 0.0}
# I1020 07:08:04.894411 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.045148026,
#  'Loss/localization_loss': 0.014572379,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12619911,
#  'learning_rate': 0.0}
# 2022-10-20 07:08:11.368701: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 63500 per-step time 0.074s
# I1020 07:08:12.290116 140189347592064 model_lib_v2.py:707] Step 63500 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.102673106,
#  'Loss/localization_loss': 0.053635202,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.22278702,
#  'learning_rate': 0.0}
# I1020 07:08:12.290420 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.102673106,
#  'Loss/localization_loss': 0.053635202,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.22278702,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 63600 per-step time 0.073s
# I1020 07:08:19.603678 140189347592064 model_lib_v2.py:707] Step 63600 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.07639127,
#  'Loss/localization_loss': 0.020073703,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16294369,
#  'learning_rate': 0.0}
# I1020 07:08:19.603970 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.07639127,
#  'Loss/localization_loss': 0.020073703,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16294369,
#  'learning_rate': 0.0}
# 2022-10-20 07:08:22.781854: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 63700 per-step time 0.076s
# I1020 07:08:27.220065 140189347592064 model_lib_v2.py:707] Step 63700 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.06472941,
#  'Loss/localization_loss': 0.023394339,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15460245,
#  'learning_rate': 0.0}
# I1020 07:08:27.220403 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06472941,
#  'Loss/localization_loss': 0.023394339,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15460245,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 63800 per-step time 0.072s
# I1020 07:08:34.458120 140189347592064 model_lib_v2.py:707] Step 63800 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.04562908,
#  'Loss/localization_loss': 0.014507729,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12661552,
#  'learning_rate': 0.0}
# I1020 07:08:34.458458 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.04562908,
#  'Loss/localization_loss': 0.014507729,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12661552,
#  'learning_rate': 0.0}
# 2022-10-20 07:08:35.717689: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 63900 per-step time 0.073s
# I1020 07:08:41.784954 140189347592064 model_lib_v2.py:707] Step 63900 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.044990174,
#  'Loss/localization_loss': 0.008689369,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.120158255,
#  'learning_rate': 0.0}
# I1020 07:08:41.785261 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.044990174,
#  'Loss/localization_loss': 0.008689369,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.120158255,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 64000 per-step time 0.074s
# I1020 07:08:49.168862 140189347592064 model_lib_v2.py:707] Step 64000 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.17343892,
#  'Loss/localization_loss': 0.12117505,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.36109266,
#  'learning_rate': 0.0}
# I1020 07:08:49.169232 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.17343892,
#  'Loss/localization_loss': 0.12117505,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.36109266,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 64100 per-step time 0.084s
# I1020 07:08:57.589884 140189347592064 model_lib_v2.py:707] Step 64100 per-step time 0.084s
# INFO:tensorflow:{'Loss/classification_loss': 0.091105774,
#  'Loss/localization_loss': 0.016484905,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.17406937,
#  'learning_rate': 0.0}
# I1020 07:08:57.590222 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.091105774,
#  'Loss/localization_loss': 0.016484905,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.17406937,
#  'learning_rate': 0.0}
# 2022-10-20 07:08:58.167930: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 64200 per-step time 0.077s
# I1020 07:09:05.250788 140189347592064 model_lib_v2.py:707] Step 64200 per-step time 0.077s
# INFO:tensorflow:{'Loss/classification_loss': 0.061482605,
#  'Loss/localization_loss': 0.022249497,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1502108,
#  'learning_rate': 0.0}
# I1020 07:09:05.251120 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.061482605,
#  'Loss/localization_loss': 0.022249497,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1502108,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 64300 per-step time 0.075s
# I1020 07:09:12.774105 140189347592064 model_lib_v2.py:707] Step 64300 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.061011612,
#  'Loss/localization_loss': 0.018520806,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14601111,
#  'learning_rate': 0.0}
# I1020 07:09:12.774405 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.061011612,
#  'Loss/localization_loss': 0.018520806,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14601111,
#  'learning_rate': 0.0}
# 2022-10-20 07:09:16.499100: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 64400 per-step time 0.075s
# I1020 07:09:20.283394 140189347592064 model_lib_v2.py:707] Step 64400 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.08052757,
#  'Loss/localization_loss': 0.015334409,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16234067,
#  'learning_rate': 0.0}
# I1020 07:09:20.283683 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.08052757,
#  'Loss/localization_loss': 0.015334409,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16234067,
#  'learning_rate': 0.0}
# 2022-10-20 07:09:26.090155: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 64500 per-step time 0.074s
# I1020 07:09:27.713627 140189347592064 model_lib_v2.py:707] Step 64500 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.04143581,
#  'Loss/localization_loss': 0.009116336,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11703086,
#  'learning_rate': 0.0}
# I1020 07:09:27.713922 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.04143581,
#  'Loss/localization_loss': 0.009116336,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11703086,
#  'learning_rate': 0.0}
# 2022-10-20 07:09:28.702015: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 64600 per-step time 0.074s
# I1020 07:09:35.131289 140189347592064 model_lib_v2.py:707] Step 64600 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.06202586,
#  'Loss/localization_loss': 0.030912584,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15941715,
#  'learning_rate': 0.0}
# I1020 07:09:35.131582 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06202586,
#  'Loss/localization_loss': 0.030912584,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15941715,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 64700 per-step time 0.074s
# I1020 07:09:42.558109 140189347592064 model_lib_v2.py:707] Step 64700 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.05909373,
#  'Loss/localization_loss': 0.018252328,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14382476,
#  'learning_rate': 0.0}
# I1020 07:09:42.558392 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.05909373,
#  'Loss/localization_loss': 0.018252328,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14382476,
#  'learning_rate': 0.0}
# 2022-10-20 07:09:46.752188: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 64800 per-step time 0.074s
# I1020 07:09:49.999174 140189347592064 model_lib_v2.py:707] Step 64800 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.05146486,
#  'Loss/localization_loss': 0.015461598,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13340516,
#  'learning_rate': 0.0}
# I1020 07:09:49.999471 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.05146486,
#  'Loss/localization_loss': 0.015461598,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13340516,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 64900 per-step time 0.073s
# I1020 07:09:57.332536 140189347592064 model_lib_v2.py:707] Step 64900 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.03783946,
#  'Loss/localization_loss': 0.0055169864,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.109835155,
#  'learning_rate': 0.0}
# I1020 07:09:57.332842 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.03783946,
#  'Loss/localization_loss': 0.0055169864,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.109835155,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 65000 per-step time 0.073s
# I1020 07:10:04.654559 140189347592064 model_lib_v2.py:707] Step 65000 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.03635192,
#  'Loss/localization_loss': 0.00865961,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.111490235,
#  'learning_rate': 0.0}
# I1020 07:10:04.654860 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.03635192,
#  'Loss/localization_loss': 0.00865961,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.111490235,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 65100 per-step time 0.082s
# I1020 07:10:12.853659 140189347592064 model_lib_v2.py:707] Step 65100 per-step time 0.082s
# INFO:tensorflow:{'Loss/classification_loss': 0.03903448,
#  'Loss/localization_loss': 0.013404563,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11891775,
#  'learning_rate': 0.0}
# I1020 07:10:12.853990 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.03903448,
#  'Loss/localization_loss': 0.013404563,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11891775,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 65200 per-step time 0.074s
# I1020 07:10:20.267120 140189347592064 model_lib_v2.py:707] Step 65200 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.06609511,
#  'Loss/localization_loss': 0.020460634,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15303445,
#  'learning_rate': 0.0}
# I1020 07:10:20.267414 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06609511,
#  'Loss/localization_loss': 0.020460634,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15303445,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 65300 per-step time 0.075s
# I1020 07:10:27.747624 140189347592064 model_lib_v2.py:707] Step 65300 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.05533651,
#  'Loss/localization_loss': 0.014805566,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13662079,
#  'learning_rate': 0.0}
# I1020 07:10:27.747908 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.05533651,
#  'Loss/localization_loss': 0.014805566,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13662079,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 65400 per-step time 0.072s
# I1020 07:10:34.938229 140189347592064 model_lib_v2.py:707] Step 65400 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.034461793,
#  'Loss/localization_loss': 0.012115528,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11305603,
#  'learning_rate': 0.0}
# I1020 07:10:34.938578 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.034461793,
#  'Loss/localization_loss': 0.012115528,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11305603,
#  'learning_rate': 0.0}
# 2022-10-20 07:10:36.433776: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# 2022-10-20 07:10:42.140676: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 65500 per-step time 0.076s
# I1020 07:10:42.530251 140189347592064 model_lib_v2.py:707] Step 65500 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.03006301,
#  'Loss/localization_loss': 0.010764316,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10730603,
#  'learning_rate': 0.0}
# I1020 07:10:42.530598 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.03006301,
#  'Loss/localization_loss': 0.010764316,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10730603,
#  'learning_rate': 0.0}
# 2022-10-20 07:10:44.658399: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 65600 per-step time 0.075s
# I1020 07:10:50.000226 140189347592064 model_lib_v2.py:707] Step 65600 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.039885152,
#  'Loss/localization_loss': 0.013654976,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12001884,
#  'learning_rate': 0.0}
# I1020 07:10:50.000530 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.039885152,
#  'Loss/localization_loss': 0.013654976,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12001884,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 65700 per-step time 0.075s
# I1020 07:10:57.452605 140189347592064 model_lib_v2.py:707] Step 65700 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.054152165,
#  'Loss/localization_loss': 0.009970625,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1306015,
#  'learning_rate': 0.0}
# I1020 07:10:57.452891 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.054152165,
#  'Loss/localization_loss': 0.009970625,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1306015,
#  'learning_rate': 0.0}
# 2022-10-20 07:10:58.878373: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# 2022-10-20 07:11:00.430281: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 65800 per-step time 0.074s
# I1020 07:11:04.886833 140189347592064 model_lib_v2.py:707] Step 65800 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.032015353,
#  'Loss/localization_loss': 0.013002997,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11149706,
#  'learning_rate': 0.0}
# I1020 07:11:04.887178 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.032015353,
#  'Loss/localization_loss': 0.013002997,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.11149706,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 65900 per-step time 0.108s
# I1020 07:11:15.704210 140189347592064 model_lib_v2.py:707] Step 65900 per-step time 0.108s
# INFO:tensorflow:{'Loss/classification_loss': 0.06851681,
#  'Loss/localization_loss': 0.021976875,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1569724,
#  'learning_rate': 0.0}
# I1020 07:11:15.704494 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06851681,
#  'Loss/localization_loss': 0.021976875,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1569724,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 66000 per-step time 0.073s
# I1020 07:11:23.010561 140189347592064 model_lib_v2.py:707] Step 66000 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.03915741,
#  'Loss/localization_loss': 0.011055885,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.116692,
#  'learning_rate': 0.0}
# I1020 07:11:23.010841 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.03915741,
#  'Loss/localization_loss': 0.011055885,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.116692,
#  'learning_rate': 0.0}
# 2022-10-20 07:11:24.655356: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 66100 per-step time 0.087s
# I1020 07:11:31.723393 140189347592064 model_lib_v2.py:707] Step 66100 per-step time 0.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.039828766,
#  'Loss/localization_loss': 0.011128919,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.117436394,
#  'learning_rate': 0.0}
# I1020 07:11:31.723695 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.039828766,
#  'Loss/localization_loss': 0.011128919,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.117436394,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 66200 per-step time 0.074s
# I1020 07:11:39.163673 140189347592064 model_lib_v2.py:707] Step 66200 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.027770042,
#  'Loss/localization_loss': 0.008392492,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10264124,
#  'learning_rate': 0.0}
# I1020 07:11:39.164027 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.027770042,
#  'Loss/localization_loss': 0.008392492,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10264124,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 66300 per-step time 0.074s
# I1020 07:11:46.539411 140189347592064 model_lib_v2.py:707] Step 66300 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.04650235,
#  'Loss/localization_loss': 0.016154867,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12913594,
#  'learning_rate': 0.0}
# I1020 07:11:46.539782 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.04650235,
#  'Loss/localization_loss': 0.016154867,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12913594,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 66400 per-step time 0.076s
# I1020 07:11:54.097073 140189347592064 model_lib_v2.py:707] Step 66400 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.11609059,
#  'Loss/localization_loss': 0.05231415,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.23488346,
#  'learning_rate': 0.0}
# I1020 07:11:54.097361 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.11609059,
#  'Loss/localization_loss': 0.05231415,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.23488346,
#  'learning_rate': 0.0}
# 2022-10-20 07:11:57.090516: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 66500 per-step time 0.075s
# I1020 07:12:01.578519 140189347592064 model_lib_v2.py:707] Step 66500 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.044136383,
#  'Loss/localization_loss': 0.012034264,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12264936,
#  'learning_rate': 0.0}
# I1020 07:12:01.578819 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.044136383,
#  'Loss/localization_loss': 0.012034264,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12264936,
#  'learning_rate': 0.0}
# 2022-10-20 07:12:07.213382: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 66600 per-step time 0.073s
# I1020 07:12:08.918520 140189347592064 model_lib_v2.py:707] Step 66600 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.050328,
#  'Loss/localization_loss': 0.019066509,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13587323,
#  'learning_rate': 0.0}
# I1020 07:12:08.918820 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.050328,
#  'Loss/localization_loss': 0.019066509,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13587323,
#  'learning_rate': 0.0}
# 2022-10-20 07:12:11.522858: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 66700 per-step time 0.073s
# I1020 07:12:16.245044 140189347592064 model_lib_v2.py:707] Step 66700 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.09378455,
#  'Loss/localization_loss': 0.053966105,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.21422935,
#  'learning_rate': 0.0}
# I1020 07:12:16.245336 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.09378455,
#  'Loss/localization_loss': 0.053966105,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.21422935,
#  'learning_rate': 0.0}
# 2022-10-20 07:12:20.551440: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 66800 per-step time 0.073s
# I1020 07:12:23.529406 140189347592064 model_lib_v2.py:707] Step 66800 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.028341355,
#  'Loss/localization_loss': 0.0063461717,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10116623,
#  'learning_rate': 0.0}
# I1020 07:12:23.529743 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.028341355,
#  'Loss/localization_loss': 0.0063461717,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10116623,
#  'learning_rate': 0.0}
# 2022-10-20 07:12:23.831254: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 66900 per-step time 0.075s
# I1020 07:12:30.985625 140189347592064 model_lib_v2.py:707] Step 66900 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.046482,
#  'Loss/localization_loss': 0.014502653,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12746336,
#  'learning_rate': 0.0}
# I1020 07:12:30.985940 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.046482,
#  'Loss/localization_loss': 0.014502653,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12746336,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 67000 per-step time 0.077s
# I1020 07:12:38.638078 140189347592064 model_lib_v2.py:707] Step 67000 per-step time 0.077s
# INFO:tensorflow:{'Loss/classification_loss': 0.038072642,
#  'Loss/localization_loss': 0.008823636,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.113374986,
#  'learning_rate': 0.0}
# I1020 07:12:38.638374 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.038072642,
#  'Loss/localization_loss': 0.008823636,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.113374986,
#  'learning_rate': 0.0}
# 2022-10-20 07:12:42.096529: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 67100 per-step time 0.083s
# I1020 07:12:46.935823 140189347592064 model_lib_v2.py:707] Step 67100 per-step time 0.083s
# INFO:tensorflow:{'Loss/classification_loss': 0.031613003,
#  'Loss/localization_loss': 0.0066663544,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10475807,
#  'learning_rate': 0.0}
# I1020 07:12:46.936135 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.031613003,
#  'Loss/localization_loss': 0.0066663544,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10475807,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 67200 per-step time 0.074s
# I1020 07:12:54.284254 140189347592064 model_lib_v2.py:707] Step 67200 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.14273681,
#  'Loss/localization_loss': 0.08746078,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.29667628,
#  'learning_rate': 0.0}
# I1020 07:12:54.284556 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.14273681,
#  'Loss/localization_loss': 0.08746078,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.29667628,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 67300 per-step time 0.077s
# I1020 07:13:01.992286 140189347592064 model_lib_v2.py:707] Step 67300 per-step time 0.077s
# INFO:tensorflow:{'Loss/classification_loss': 0.054492224,
#  'Loss/localization_loss': 0.031097522,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15206845,
#  'learning_rate': 0.0}
# I1020 07:13:01.992591 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.054492224,
#  'Loss/localization_loss': 0.031097522,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15206845,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 67400 per-step time 0.076s
# I1020 07:13:09.563013 140189347592064 model_lib_v2.py:707] Step 67400 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.103276715,
#  'Loss/localization_loss': 0.079826325,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.24958175,
#  'learning_rate': 0.0}
# I1020 07:13:09.563316 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.103276715,
#  'Loss/localization_loss': 0.079826325,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.24958175,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 67500 per-step time 0.075s
# I1020 07:13:17.099659 140189347592064 model_lib_v2.py:707] Step 67500 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.0645707,
#  'Loss/localization_loss': 0.0124472035,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1434966,
#  'learning_rate': 0.0}
# I1020 07:13:17.099951 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.0645707,
#  'Loss/localization_loss': 0.0124472035,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1434966,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 67600 per-step time 0.075s
# I1020 07:13:24.632688 140189347592064 model_lib_v2.py:707] Step 67600 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.043338925,
#  'Loss/localization_loss': 0.011251326,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.121068954,
#  'learning_rate': 0.0}
# I1020 07:13:24.633043 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.043338925,
#  'Loss/localization_loss': 0.011251326,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.121068954,
#  'learning_rate': 0.0}
# 2022-10-20 07:13:31.977773: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# ...
# INFO:tensorflow:Step 97600 per-step time 0.075s
# I1020 07:51:35.531334 140189347592064 model_lib_v2.py:707] Step 97600 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.08490648,
#  'Loss/localization_loss': 0.032437336,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.18382251,
#  'learning_rate': 0.0}
# I1020 07:51:35.531623 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.08490648,
#  'Loss/localization_loss': 0.032437336,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.18382251,
#  'learning_rate': 0.0}
# 2022-10-20 07:51:37.056908: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 97700 per-step time 0.073s
# I1020 07:51:42.868180 140189347592064 model_lib_v2.py:707] Step 97700 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.09524537,
#  'Loss/localization_loss': 0.0641286,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.22585267,
#  'learning_rate': 0.0}
# I1020 07:51:42.868474 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.09524537,
#  'Loss/localization_loss': 0.0641286,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.22585267,
#  'learning_rate': 0.0}
# 2022-10-20 07:51:46.811858: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 97800 per-step time 0.072s
# I1020 07:51:50.112199 140189347592064 model_lib_v2.py:707] Step 97800 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.06608021,
#  'Loss/localization_loss': 0.028325979,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16088489,
#  'learning_rate': 0.0}
# I1020 07:51:50.112498 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06608021,
#  'Loss/localization_loss': 0.028325979,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16088489,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 97900 per-step time 0.072s
# I1020 07:51:57.338962 140189347592064 model_lib_v2.py:707] Step 97900 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.055270035,
#  'Loss/localization_loss': 0.017757604,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13950634,
#  'learning_rate': 0.0}
# I1020 07:51:57.339322 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.055270035,
#  'Loss/localization_loss': 0.017757604,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13950634,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98000 per-step time 0.074s
# I1020 07:52:04.689949 140189347592064 model_lib_v2.py:707] Step 98000 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.049480367,
#  'Loss/localization_loss': 0.011033384,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12699246,
#  'learning_rate': 0.0}
# I1020 07:52:04.690310 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.049480367,
#  'Loss/localization_loss': 0.011033384,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.12699246,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98100 per-step time 0.083s
# I1020 07:52:13.032070 140189347592064 model_lib_v2.py:707] Step 98100 per-step time 0.083s
# INFO:tensorflow:{'Loss/classification_loss': 0.05603514,
#  'Loss/localization_loss': 0.022560688,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14507453,
#  'learning_rate': 0.0}
# I1020 07:52:13.032375 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.05603514,
#  'Loss/localization_loss': 0.022560688,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14507453,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98200 per-step time 0.076s
# I1020 07:52:20.607774 140189347592064 model_lib_v2.py:707] Step 98200 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.06696808,
#  'Loss/localization_loss': 0.02509731,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1585441,
#  'learning_rate': 0.0}
# I1020 07:52:20.608128 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06696808,
#  'Loss/localization_loss': 0.02509731,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1585441,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98300 per-step time 0.074s
# I1020 07:52:28.025661 140189347592064 model_lib_v2.py:707] Step 98300 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.022071943,
#  'Loss/localization_loss': 0.007118711,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09566936,
#  'learning_rate': 0.0}
# I1020 07:52:28.026019 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.022071943,
#  'Loss/localization_loss': 0.007118711,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09566936,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98400 per-step time 0.074s
# I1020 07:52:35.419894 140189347592064 model_lib_v2.py:707] Step 98400 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.05267826,
#  'Loss/localization_loss': 0.01337056,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13252753,
#  'learning_rate': 0.0}
# I1020 07:52:35.420219 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.05267826,
#  'Loss/localization_loss': 0.01337056,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13252753,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98500 per-step time 0.078s
# I1020 07:52:43.171797 140189347592064 model_lib_v2.py:707] Step 98500 per-step time 0.078s
# INFO:tensorflow:{'Loss/classification_loss': 0.07109231,
#  'Loss/localization_loss': 0.016382439,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15395346,
#  'learning_rate': 0.0}
# I1020 07:52:43.172119 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.07109231,
#  'Loss/localization_loss': 0.016382439,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15395346,
#  'learning_rate': 0.0}
# 2022-10-20 07:52:44.753065: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 98600 per-step time 0.072s
# I1020 07:52:50.421091 140189347592064 model_lib_v2.py:707] Step 98600 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.07973891,
#  'Loss/localization_loss': 0.021947166,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16816479,
#  'learning_rate': 0.0}
# I1020 07:52:50.421379 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.07973891,
#  'Loss/localization_loss': 0.021947166,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16816479,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 98700 per-step time 0.076s
# I1020 07:52:57.970185 140189347592064 model_lib_v2.py:707] Step 98700 per-step time 0.076s
# INFO:tensorflow:{'Loss/classification_loss': 0.096226774,
#  'Loss/localization_loss': 0.07005432,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.2327598,
#  'learning_rate': 0.0}
# I1020 07:52:57.970480 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.096226774,
#  'Loss/localization_loss': 0.07005432,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.2327598,
#  'learning_rate': 0.0}
# 2022-10-20 07:53:05.360477: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# 2022-10-20 07:53:05.724792: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 98800 per-step time 0.081s
# I1020 07:53:06.079156 140189347592064 model_lib_v2.py:707] Step 98800 per-step time 0.081s
# INFO:tensorflow:{'Loss/classification_loss': 0.033593252,
#  'Loss/localization_loss': 0.009165054,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.109237015,
#  'learning_rate': 0.0}
# I1020 07:53:06.079506 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.033593252,
#  'Loss/localization_loss': 0.009165054,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.109237015,
#  'learning_rate': 0.0}
# 2022-10-20 07:53:07.607442: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 98900 per-step time 0.101s
# I1020 07:53:16.225809 140189347592064 model_lib_v2.py:707] Step 98900 per-step time 0.101s
# INFO:tensorflow:{'Loss/classification_loss': 0.05540948,
#  'Loss/localization_loss': 0.015780574,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13766876,
#  'learning_rate': 0.0}
# I1020 07:53:16.226135 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.05540948,
#  'Loss/localization_loss': 0.015780574,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13766876,
#  'learning_rate': 0.0}
# 2022-10-20 07:53:22.370740: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 99000 per-step time 0.074s
# I1020 07:53:23.660119 140189347592064 model_lib_v2.py:707] Step 99000 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.05291217,
#  'Loss/localization_loss': 0.017240018,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1366309,
#  'learning_rate': 0.0}
# I1020 07:53:23.660415 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.05291217,
#  'Loss/localization_loss': 0.017240018,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.1366309,
#  'learning_rate': 0.0}
# 2022-10-20 07:53:26.632949: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 99100 per-step time 0.082s
# I1020 07:53:31.839425 140189347592064 model_lib_v2.py:707] Step 99100 per-step time 0.082s
# INFO:tensorflow:{'Loss/classification_loss': 0.035573576,
#  'Loss/localization_loss': 0.014725764,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.116778046,
#  'learning_rate': 0.0}
# I1020 07:53:31.839728 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.035573576,
#  'Loss/localization_loss': 0.014725764,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.116778046,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99200 per-step time 0.075s
# I1020 07:53:39.317445 140189347592064 model_lib_v2.py:707] Step 99200 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.11586984,
#  'Loss/localization_loss': 0.039389767,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.22173831,
#  'learning_rate': 0.0}
# I1020 07:53:39.317752 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.11586984,
#  'Loss/localization_loss': 0.039389767,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.22173831,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99300 per-step time 0.075s
# I1020 07:53:46.757606 140189347592064 model_lib_v2.py:707] Step 99300 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.06027401,
#  'Loss/localization_loss': 0.03400655,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16075927,
#  'learning_rate': 0.0}
# I1020 07:53:46.757913 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.06027401,
#  'Loss/localization_loss': 0.03400655,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.16075927,
#  'learning_rate': 0.0}
# 2022-10-20 07:53:54.127022: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 99400 per-step time 0.074s
# I1020 07:53:54.200919 140189347592064 model_lib_v2.py:707] Step 99400 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.020516148,
#  'Loss/localization_loss': 0.006946366,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09394122,
#  'learning_rate': 0.0}
# I1020 07:53:54.201209 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.020516148,
#  'Loss/localization_loss': 0.006946366,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09394122,
#  'learning_rate': 0.0}
# 2022-10-20 07:53:57.007301: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 99500 per-step time 0.072s
# I1020 07:54:01.446232 140189347592064 model_lib_v2.py:707] Step 99500 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.048755478,
#  'Loss/localization_loss': 0.03173946,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14697364,
#  'learning_rate': 0.0}
# I1020 07:54:01.446588 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.048755478,
#  'Loss/localization_loss': 0.03173946,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.14697364,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99600 per-step time 0.074s
# I1020 07:54:08.830234 140189347592064 model_lib_v2.py:707] Step 99600 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.024707021,
#  'Loss/localization_loss': 0.0059998287,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09718555,
#  'learning_rate': 0.0}
# I1020 07:54:08.830535 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.024707021,
#  'Loss/localization_loss': 0.0059998287,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.09718555,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99700 per-step time 0.075s
# I1020 07:54:16.310131 140189347592064 model_lib_v2.py:707] Step 99700 per-step time 0.075s
# INFO:tensorflow:{'Loss/classification_loss': 0.09971292,
#  'Loss/localization_loss': 0.042476688,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.20866832,
#  'learning_rate': 0.0}
# I1020 07:54:16.310465 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.09971292,
#  'Loss/localization_loss': 0.042476688,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.20866832,
#  'learning_rate': 0.0}
# INFO:tensorflow:Step 99800 per-step time 0.074s
# I1020 07:54:23.668138 140189347592064 model_lib_v2.py:707] Step 99800 per-step time 0.074s
# INFO:tensorflow:{'Loss/classification_loss': 0.075828865,
#  'Loss/localization_loss': 0.013916084,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15622365,
#  'learning_rate': 0.0}
# I1020 07:54:23.668442 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.075828865,
#  'Loss/localization_loss': 0.013916084,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.15622365,
#  'learning_rate': 0.0}
# 2022-10-20 07:54:28.825569: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 99900 per-step time 0.072s
# I1020 07:54:30.891848 140189347592064 model_lib_v2.py:707] Step 99900 per-step time 0.072s
# INFO:tensorflow:{'Loss/classification_loss': 0.029547079,
#  'Loss/localization_loss': 0.005302692,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10132848,
#  'learning_rate': 0.0}
# I1020 07:54:30.892214 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.029547079,
#  'Loss/localization_loss': 0.005302692,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.10132848,
#  'learning_rate': 0.0}
# 2022-10-20 07:54:31.993154: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: Not recognizing known sRGB profile that has been edited
# INFO:tensorflow:Step 100000 per-step time 0.073s
# I1020 07:54:38.165359 140189347592064 model_lib_v2.py:707] Step 100000 per-step time 0.073s
# INFO:tensorflow:{'Loss/classification_loss': 0.054157477,
#  'Loss/localization_loss': 0.0104819415,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13111812,
#  'learning_rate': 0.0}
# I1020 07:54:38.165650 140189347592064 model_lib_v2.py:708] {'Loss/classification_loss': 0.054157477,
#  'Loss/localization_loss': 0.0104819415,
#  'Loss/regularization_loss': 0.06647871,
#  'Loss/total_loss': 0.13111812,
#  'learning_rate': 0.0}

# %% [markdown]
# # 7. Evaluate the Model

# %%
print(TRAINING_SCRIPT)               
print(paths['CHECKPOINT_PATH'])      
print(files['PIPELINE_CONFIG'])
paths['CHECKPOINT_PATH']
# Out:
# Tensorflow/models/research/object_detection/model_main_tf2.py
# Tensorflow/workspace/models/my_ssd_mobnet
# Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config
# 'Tensorflow/workspace/models/my_ssd_mobnet'

# %%
command = "python {} \
--model_dir={} \
--pipeline_config_path={} \
--checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet

# %%
# !{command}
# Out:
# 2022-10-20 07:54:41.972628: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-20 07:54:42.870266: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 07:54:42.870429: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 07:54:42.870450: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1020 07:54:45.288148 140371942946688 model_lib_v2.py:1090] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I1020 07:54:45.288372 140371942946688 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1020 07:54:45.288471 140371942946688 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1020 07:54:45.288554 140371942946688 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W1020 07:54:45.288660 140371942946688 model_lib_v2.py:1110] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2022-10-20 07:54:46.086697: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# I1020 07:54:46.138123 140371942946688 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# I1020 07:54:46.138572 140371942946688 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1020 07:54:46.138728 140371942946688 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1020 07:54:46.138799 140371942946688 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1020 07:54:46.142146 140371942946688 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1020 07:54:46.158186 140371942946688 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1020 07:54:50.179569 140371942946688 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1020 07:54:51.333902 140371942946688 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# I1020 07:54:53.965462 140371942946688 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# INFO:tensorflow:Found new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet/ckpt-101
# I1020 07:54:53.968593 140371942946688 checkpoint_utils.py:151] Found new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet/ckpt-101
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   "`tf.keras.backend.set_learning_phase` is deprecated and "
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1020 07:55:17.484088 140371942946688 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I1020 07:55:17.509140 140371942946688 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W1020 07:55:17.653935 140371942946688 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I1020 07:55:23.450378 140371942946688 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Performing evaluation on 128 images.
# I1020 07:55:24.571280 140371942946688 coco_evaluation.py:293] Performing evaluation on 128 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I1020 07:55:24.571961 140371942946688 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# I1020 07:55:24.579140 140371942946688 coco_tools.py:138] DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.75s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.679
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.540
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.584
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.840
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.578
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.685
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.863
# INFO:tensorflow:Eval metrics at step 100000
# I1020 07:55:25.491837 140371942946688 model_lib_v2.py:1015] Eval metrics at step 100000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.450943
# I1020 07:55:25.505076 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.450943
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.679049
# I1020 07:55:25.506614 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.679049
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.540137
# I1020 07:55:25.508098 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.540137
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.308806
# I1020 07:55:25.509721 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.308806
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.584488
# I1020 07:55:25.511138 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.584488
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.839679
# I1020 07:55:25.512530 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.839679
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.322687
# I1020 07:55:25.513937 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.322687
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.524620
# I1020 07:55:25.515358 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.524620
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.578472
# I1020 07:55:25.516778 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.578472
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.481385
# I1020 07:55:25.518169 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.481385
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.684821
# I1020 07:55:25.519538 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.684821
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.862500
# I1020 07:55:25.521141 140371942946688 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.862500
# INFO:tensorflow:	+ Loss/localization_loss: 0.108650
# I1020 07:55:25.522183 140371942946688 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.108650
# INFO:tensorflow:	+ Loss/classification_loss: 0.261196
# I1020 07:55:25.523292 140371942946688 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.261196
# INFO:tensorflow:	+ Loss/regularization_loss: 0.066479
# I1020 07:55:25.524384 140371942946688 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.066479
# INFO:tensorflow:	+ Loss/total_loss: 0.436325
# I1020 07:55:25.525457 140371942946688 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.436325
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# I1020 07:59:54.027985 140371942946688 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "Tensorflow/models/research/object_detection/model_main_tf2.py", line 89, in main
#     wait_interval=300, timeout=FLAGS.eval_timeout)
#   File "/usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py", line 1136, in eval_continuously
#     checkpoint_dir, timeout=timeout, min_interval_secs=wait_interval):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 201, in checkpoints_iterator
#     checkpoint_dir, checkpoint_path, timeout=timeout)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 149, in wait_for_new_checkpoint
#     time.sleep(seconds_to_sleep)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "Tensorflow/models/research/object_detection/model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 321, in run
#     if FLAGS.pdb_post_mortem and sys.stdout.isatty():
#   File "/usr/local/lib/python3.7/dist-packages/absl/flags/_flagvalues.py", line 470, in __getattr__
#     fl = self._flags()
# KeyboardInterrupt

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-101')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
paths['CHECKPOINT_PATH']
# Out:
# 'Tensorflow/workspace/models/my_ssd_mobnet'

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
from pylab import rcParams
# %matplotlib inline

# %%
files['LABELMAP']
# Out:
# 'Tensorflow/workspace/annotations/label_map.pbtxt'

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
category_index
# Out:
# {1: {'id': 1, 'name': 'with_mask'},
#  2: {'id': 2, 'name': 'without_mask'},
#  3: {'id': 3, 'name': 'mask_weared_incorrect'}}

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', '/content/drive/MyDrive/TFOD/Tensorflow/workspace/images/test/maksssksksss725.png')

# %%
MAX_BOXES_TO_DRAW = 5
MIN_SCORE_THRES = 0.6

# %%
def detect_func(img, MAX_BOXES_TO_DRAW, MIN_SCORE_THRES):
  image_np = np.array(img)

  input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
  detections = detect_fn(input_tensor)

  num_detections = int(detections.pop('num_detections'))
  detections = {key: value[0, :num_detections].numpy()
                for key, value in detections.items()}
  detections['num_detections'] = num_detections

  # detection_classes should be ints.
  detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

  label_id_offset = 1
  image_np_with_detections = image_np.copy()

  viz_utils.visualize_boxes_and_labels_on_image_array(
              image_np_with_detections,
              detections['detection_boxes'],
              detections['detection_classes']+label_id_offset,
              detections['detection_scores'],
              category_index,
              use_normalized_coordinates=True,
              max_boxes_to_draw=MAX_BOXES_TO_DRAW,
              min_score_thresh=MIN_SCORE_THRES,
              agnostic_mode=False)
  
  return image_np_with_detections

# %%
rcParams['figure.figsize'] = 20, 10
img = cv2.imread(IMAGE_PATH)

image_np_with_detections = detect_func(img, MAX_BOXES_TO_DRAW, MIN_SCORE_THRES)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Some Random Images

# %%
testImagesPath = []
for root, dirs, files in os.walk(os.path.join(paths['IMAGE_PATH'], 'test')):
    for filename in files:
        if filename.find(".xml") == -1:
          testImagesPath.append(f"{root}/{filename}")

#testImagesPath

# %%
#Some random images to display at a time along with their true and random labels
rcParams['figure.figsize'] = 20, 10

num_row = 2
num_col = 4

imageId = np.random.randint(0, len(testImagesPath), num_row * num_col)

fig, axes = plt.subplots(num_row, num_col)

for i in range(0, num_row):
    for j in range(0, num_col):
        k = (i*num_col) + j

        img = cv2.imread(testImagesPath[imageId[k]])
        
        image_np_with_detections = detect_func(img, MAX_BOXES_TO_DRAW, MIN_SCORE_THRES)

        axes[i,j].imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
        # axes[i,j].set_title("", fontsize=14)
        #axes[i,j].axis('off')
        #fig.suptitle("", fontsize = 18) 

plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam (Local)

# %%
#!pip uninstall opencv-python-headless -y

# %%
# cap = cv2.VideoCapture(0)
# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# while cap.isOpened(): 
#     ret, frame = cap.read()
#     image_np = np.array(frame)
    
#     input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
#     detections = detect_fn(input_tensor)
    
#     num_detections = int(detections.pop('num_detections'))
#     detections = {key: value[0, :num_detections].numpy()
#                   for key, value in detections.items()}
#     detections['num_detections'] = num_detections

#     # detection_classes should be ints.
#     detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

#     label_id_offset = 1
#     image_np_with_detections = image_np.copy()

#     viz_utils.visualize_boxes_and_labels_on_image_array(
#                 image_np_with_detections,
#                 detections['detection_boxes'],
#                 detections['detection_classes']+label_id_offset,
#                 detections['detection_scores'],
#                 category_index,
#                 use_normalized_coordinates=True,
#                 max_boxes_to_draw=5,
#                 min_score_thresh=.8,
#                 agnostic_mode=False)

#     cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
#     if cv2.waitKey(10) & 0xFF == ord('q'):
#         cap.release()
#         cv2.destroyAllWindows()
#         break

# %% [markdown]
# # 11. REAL TIME: From Google Colab Access, Local Webcam for Images and Video
#
# [Reference Code Snippet](https://colab.research.google.com/drive/1QnC7lV7oVFk5OZCm75fqbLAfD9qBy9bw?usp=sharing#scrollTo=ilLkpcKanPRb)

# %% [markdown]
# ## Images

# %%
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time

from matplotlib import pyplot as plt
from pylab import rcParams
# %matplotlib inline

# %% [markdown]
# ### Helper Functions For Images
# Below are a few helper function to make converting between different image data types and formats.

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
def detectionsColabWEBCAM(filename, detect_func):
  rcParams['figure.figsize'] = 20, 10
  img = cv2.imread(filename)
  
  image_np_with_detections = detect_func(img, MAX_BOXES_TO_DRAW, MIN_SCORE_THRES)

  plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# ## Webcam Images
# Running code on images taken from webcam is fairly straight-forward. We will utilize code within Google Colab's **Code Snippets** that has a variety of useful code functions to perform various tasks.
#
# We will be using the code snippet for **Camera Capture** to utilize your computer's webcam.

# %%
def take_photo(filename='/content/drive/MyDrive/TFOD/photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  # get photo data
  data = eval_js('takePhoto({})'.format(quality))
  # get OpenCV format image
  img = js_to_image(data) 
  # grayscale img
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  print("Shape: ", gray.shape)
  # save image
  cv2.imwrite(filename, img)

  return filename

# %% [markdown]
# ### Capture and Detect

# %%
try:
  filename = take_photo('/content/drive/MyDrive/TFOD/photo.jpg')
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  #display(Image(filename))
  detectionsColabWEBCAM(filename, detect_func)
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %% [markdown]
# ### Helper Functions for Video

# %%
# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %% [markdown]
# ### Capture and Detect: In Real Time Video inside Colab

# %%
category_index
# Out:
# {1: {'id': 1, 'name': 'with_mask'},
#  2: {'id': 2, 'name': 'without_mask'},
#  3: {'id': 3, 'name': 'mask_weared_incorrect'}}

# %%
len(category_index)
# Out:
# 3

# %%
# start streaming video from webcam
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''
count = 0 
while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    img = js_to_image(js_reply["img"])
    img_height, img_width, _ = img.shape
    
    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)

    # grayscale image for face detection
    #gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # get detections
    input_tensor = tf.convert_to_tensor(np.expand_dims(img, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)

    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
               for key, value in detections.items()}
    detections['num_detections'] = num_detections

    #print(detections['num_detections']) #100

    #detection_classes should be ints.
    #detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
        
    count = 0
    for i, j, k in zip(detections['detection_boxes'], detections['detection_scores'], detections['detection_classes'] + label_id_offset):
      if j >= 0.6:
        
        #print(i, j, k)
        #print(type(i[0].item()))
        #Converting numpy.float to python float and to list
        bboxes = getattr(i, "tolist", lambda: i)()

        ymin, xmin, ymax, xmax = bboxes
        
        #Denormalizing BBox Coordinates
        #https://stackoverflow.com/questions/48915003/get-the-bounding-box-coordinates-in-the-tensorflow-object-detection-api-tutorial 
        (left, right, top, bottom) = (xmin * img_width, xmax * img_width, 
                                      ymin * img_height, ymax * img_height)

        (left, right, top, bottom) = (int(left), int(right), int(top), int(bottom))       
        #print(left, right, top, bottom)

        #Creating BBox on Overlay Image
        np.random.seed(10)
        category_color = [np.random.randint(0, 255) for i in range(len(category_index))]
        #print(category_color)
        bbox_array = cv2.rectangle(bbox_array, (left, top), (right, bottom), (category_color[int(k - 1)], 0, 0), 2)
        bbox_array = cv2.putText(bbox_array, "{} [{:.2f}]".format(category_index[k]['name'], j),
                        (left, top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        (category_color[int(k - 1)], 0, 0), 2)

      else:
        continue
      count += 1

    #print("Count", count)
    
    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes

# %% [markdown]
# # 12. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
print(FREEZE_SCRIPT)
print(files['PIPELINE_CONFIG'])
print(paths['CHECKPOINT_PATH'])
print(paths['OUTPUT_PATH'])
# Out:
# Tensorflow/models/research/object_detection/exporter_main_v2.py
# Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config
# Tensorflow/workspace/models/my_ssd_mobnet
# Tensorflow/workspace/models/my_ssd_mobnet/export

# %%
command = "python {} --input_type=image_tensor \
--pipeline_config_path={} \
--trained_checkpoint_dir={} \
--output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/export

# %%
# !{command}
# Out:
# 2022-10-20 08:22:10.246914: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-20 08:22:11.031138: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 08:22:11.031260: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 08:22:11.031283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-10-20 08:22:13.789309: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1020 08:22:14.068868 139965705406336 deprecation.py:628] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f4bc0443e10>, because it is not built.
# W1020 08:22:33.852917 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f4bc0443e10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f4b4d6ae110>, because it is not built.
# W1020 08:22:34.103296 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f4b4d6ae110>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d7daf90>, because it is not built.
# W1020 08:22:34.103502 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d7daf90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b661b6550>, because it is not built.
# W1020 08:22:34.103617 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b661b6550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f4b4d734210>, because it is not built.
# W1020 08:22:34.103708 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f4b4d734210>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d7e7750>, because it is not built.
# W1020 08:22:34.103795 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d7e7750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d6f1dd0>, because it is not built.
# W1020 08:22:34.103877 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d6f1dd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f4b661e8750>, because it is not built.
# W1020 08:22:34.103955 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f4b661e8750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4bc024b710>, because it is not built.
# W1020 08:22:34.104040 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4bc024b710>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4bc00aac10>, because it is not built.
# W1020 08:22:34.104128 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4bc00aac10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f4b4d737790>, because it is not built.
# W1020 08:22:34.104205 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f4b4d737790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d737990>, because it is not built.
# W1020 08:22:34.104291 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d737990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b661b6050>, because it is not built.
# W1020 08:22:34.104368 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b661b6050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d614310>, because it is not built.
# W1020 08:22:34.104443 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d614310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b6605e890>, because it is not built.
# W1020 08:22:34.104519 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b6605e890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d62b750>, because it is not built.
# W1020 08:22:34.104595 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d62b750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d722290>, because it is not built.
# W1020 08:22:34.104675 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d722290>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b661e8b10>, because it is not built.
# W1020 08:22:34.104822 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b661e8b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d6d9f50>, because it is not built.
# W1020 08:22:34.104909 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d6d9f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4bc009cb90>, because it is not built.
# W1020 08:22:34.104989 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4bc009cb90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d639b10>, because it is not built.
# W1020 08:22:34.105092 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d639b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d639410>, because it is not built.
# W1020 08:22:34.105178 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d639410>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d56ec10>, because it is not built.
# W1020 08:22:34.105254 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d56ec10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d56eed0>, because it is not built.
# W1020 08:22:34.105328 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d56eed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d7e9790>, because it is not built.
# W1020 08:22:34.105404 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d7e9790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d6a1290>, because it is not built.
# W1020 08:22:34.105477 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d6a1290>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d6a1050>, because it is not built.
# W1020 08:22:34.105560 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d6a1050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d6a1550>, because it is not built.
# W1020 08:22:34.105635 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d6a1550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d6a1b50>, because it is not built.
# W1020 08:22:34.105711 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d6a1b50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d6872d0>, because it is not built.
# W1020 08:22:34.105786 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d6872d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d5a51d0>, because it is not built.
# W1020 08:22:34.105860 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d5a51d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d5a52d0>, because it is not built.
# W1020 08:22:34.105934 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d5a52d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b66289050>, because it is not built.
# W1020 08:22:34.106009 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b66289050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d5a5490>, because it is not built.
# W1020 08:22:34.106100 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d5a5490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d5a5e10>, because it is not built.
# W1020 08:22:34.106176 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d5a5e10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d761350>, because it is not built.
# W1020 08:22:34.106251 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d761350>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d7463d0>, because it is not built.
# W1020 08:22:34.106328 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d7463d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d501050>, because it is not built.
# W1020 08:22:34.106403 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d501050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b66348b10>, because it is not built.
# W1020 08:22:34.106482 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b66348b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d4bdbd0>, because it is not built.
# W1020 08:22:34.106556 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d4bdbd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d4bde10>, because it is not built.
# W1020 08:22:34.106632 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d4bde10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d4bd8d0>, because it is not built.
# W1020 08:22:34.106706 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d4bd8d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d56a050>, because it is not built.
# W1020 08:22:34.106781 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d56a050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d56a990>, because it is not built.
# W1020 08:22:34.158435 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f4b4d56a990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d56a7d0>, because it is not built.
# W1020 08:22:34.158626 139965705406336 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f4b4d56a7d0>, because it is not built.
# W1020 08:22:51.206382 139965705406336 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# I1020 08:22:56.696254 139965705406336 builder_impl.py:780] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config
# I1020 08:22:57.554049 139965705406336 config_util.py:254] Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config

# %% [markdown]
# # 13. Conversion to TFJS

# %%
# !pip install tensorflowjs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflowjs in /usr/local/lib/python3.7/dist-packages (4.0.0)
# Requirement already satisfied: packaging~=20.9 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (20.9)
# Requirement already satisfied: flax>=0.5.3 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.6.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (3.19.6)
# Requirement already satisfied: tensorflow-decision-forests>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.0.1)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (5.10.0)
# Requirement already satisfied: tensorflow<3,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (2.10.0)
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: jax>=0.3.16 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.3.23)
# Requirement already satisfied: optax in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (0.1.3)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (1.0.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (5.4.1)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (12.6.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (4.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (3.2.2)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (1.21.6)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib_resources>=5.9.0->tensorflowjs) (3.9.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from jax>=0.3.16->tensorflowjs) (0.8.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/dist-packages (from jax>=0.3.16->tensorflowjs) (3.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from jax>=0.3.16->tensorflowjs) (1.3.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.7/dist-packages (from jax>=0.3.16->tensorflowjs) (1.7.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging~=20.9->tensorflowjs) (2.4.7)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=11.1->flax>=0.5.3->tensorflowjs) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=11.1->flax>=0.5.3->tensorflowjs) (2.6.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (14.0.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.0.1)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.10.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.27.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (22.9.24)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.49.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<3,>=2.10.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<3,>=2.10.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (4.13.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (3.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from tensorflow-decision-forests>=1.0.1->tensorflowjs) (1.3.5)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.7/dist-packages (from tensorflow-decision-forests>=1.0.1->tensorflowjs) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flax>=0.5.3->tensorflowjs) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flax>=0.5.3->tensorflowjs) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flax>=0.5.3->tensorflowjs) (1.4.4)
# Requirement already satisfied: chex>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from optax->flax>=0.5.3->tensorflowjs) (0.1.5)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.7/dist-packages (from optax->flax>=0.5.3->tensorflowjs) (0.3.22+cuda11.cudnn805)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax->flax>=0.5.3->tensorflowjs) (0.1.7)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax->flax>=0.5.3->tensorflowjs) (0.12.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->tensorflow-decision-forests>=1.0.1->tensorflowjs) (2022.4)

# %%
command = "tensorflowjs_converter \
--input_format=tf_saved_model \
--output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,\
num_detections,raw_detection_boxes,raw_detection_scores' \
--output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport

# %%
# !{command}
# Out:
# 2022-10-20 08:23:02.778116: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-20 08:23:03.451074: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 08:23:03.451181: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 08:23:03.451200: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-10-20 08:23:06.618131: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Writing weight file Tensorflow/workspace/models/my_ssd_mobnet/tfjsexport/model.json...

# %% [markdown]
# # 14. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} \
--pipeline_config_path={} \
--trained_checkpoint_dir={} \
--output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport

# %%
# !{command}
# Out:
# 2022-10-20 08:23:37.831987: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-20 08:23:38.623334: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 08:23:38.623443: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 08:23:38.623464: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-10-20 08:23:41.719485: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fee465ee650>, because it is not built.
# W1020 08:24:01.262197 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fee465ee650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7fee2e5b91d0>, because it is not built.
# W1020 08:24:01.899601 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7fee2e5b91d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e30a910>, because it is not built.
# W1020 08:24:01.899888 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e30a910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e3046d0>, because it is not built.
# W1020 08:24:01.900076 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e3046d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7fee2e404410>, because it is not built.
# W1020 08:24:01.900229 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7fee2e404410>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e6d0050>, because it is not built.
# W1020 08:24:01.900357 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e6d0050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee462ef910>, because it is not built.
# W1020 08:24:01.900478 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee462ef910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7fee461a8350>, because it is not built.
# W1020 08:24:01.900615 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7fee461a8350>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46211890>, because it is not built.
# W1020 08:24:01.900742 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46211890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e63d990>, because it is not built.
# W1020 08:24:01.900860 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e63d990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7fee46330d10>, because it is not built.
# W1020 08:24:01.900983 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7fee46330d10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e4aa950>, because it is not built.
# W1020 08:24:01.901113 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e4aa950>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e63b590>, because it is not built.
# W1020 08:24:01.901232 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e63b590>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46389150>, because it is not built.
# W1020 08:24:01.901316 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46389150>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e4d77d0>, because it is not built.
# W1020 08:24:01.901398 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e4d77d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e3ddbd0>, because it is not built.
# W1020 08:24:01.901476 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e3ddbd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e4d7b90>, because it is not built.
# W1020 08:24:01.901561 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e4d7b90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e4d7510>, because it is not built.
# W1020 08:24:01.901656 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e4d7510>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e7f5d10>, because it is not built.
# W1020 08:24:01.901743 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e7f5d10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e561310>, because it is not built.
# W1020 08:24:01.901822 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e561310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e561ad0>, because it is not built.
# W1020 08:24:01.901900 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e561ad0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46428890>, because it is not built.
# W1020 08:24:01.901984 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46428890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee462d75d0>, because it is not built.
# W1020 08:24:01.902075 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee462d75d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee461a89d0>, because it is not built.
# W1020 08:24:01.902158 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee461a89d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e2ca1d0>, because it is not built.
# W1020 08:24:01.902235 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e2ca1d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e2ca8d0>, because it is not built.
# W1020 08:24:01.902312 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e2ca8d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e3fee90>, because it is not built.
# W1020 08:24:01.902406 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e3fee90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e29c850>, because it is not built.
# W1020 08:24:01.902492 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e29c850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee462af410>, because it is not built.
# W1020 08:24:01.902594 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee462af410>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e669b10>, because it is not built.
# W1020 08:24:01.902685 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e669b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee462ffcd0>, because it is not built.
# W1020 08:24:01.902772 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee462ffcd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46428750>, because it is not built.
# W1020 08:24:01.902854 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46428750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee463f2ed0>, because it is not built.
# W1020 08:24:01.902935 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee463f2ed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee463f2f50>, because it is not built.
# W1020 08:24:01.903018 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee463f2f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e784e10>, because it is not built.
# W1020 08:24:01.903119 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e784e10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46244190>, because it is not built.
# W1020 08:24:01.903203 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee46244190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee4643cd50>, because it is not built.
# W1020 08:24:01.903286 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee4643cd50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e669fd0>, because it is not built.
# W1020 08:24:01.903373 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e669fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e506c10>, because it is not built.
# W1020 08:24:01.903455 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e506c10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e25b350>, because it is not built.
# W1020 08:24:01.903536 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e25b350>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e25b650>, because it is not built.
# W1020 08:24:01.903625 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e25b650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e25b150>, because it is not built.
# W1020 08:24:01.903712 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e25b150>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e25bdd0>, because it is not built.
# W1020 08:24:01.903789 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee2e25bdd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e25bfd0>, because it is not built.
# W1020 08:24:01.903869 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7fee2e25bfd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee463cc710>, because it is not built.
# W1020 08:24:01.995335 140665259353984 save_impl.py:68] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7fee463cc710>, because it is not built.
# W1020 08:24:23.450477 140665259353984 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets
# I1020 08:24:29.177136 140665259353984 builder_impl.py:780] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model --output_file=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# 2022-10-20 08:24:31.757307: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-20 08:24:32.537636: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 08:24:32.537741: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-10-20 08:24:32.537759: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-10-20 08:24:35.387296: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-10-20 08:24:45.337019: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2022-10-20 08:24:45.337093: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# Estimated count of arithmetic ops: 1.706 G  ops, equivalently 0.853 G  MACs

# %% [markdown]
# # 15. Zip and Export Models

# %%
print(paths['CHECKPOINT_PATH'])
# Out:
# Tensorflow/workspace/models/my_ssd_mobnet

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}
